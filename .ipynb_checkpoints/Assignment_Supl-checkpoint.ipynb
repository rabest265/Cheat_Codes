# %%
import pandas as pd
import os

# %%
# Make a reference to the books.csv file path
csv_path = os.path.join ("Resources" , "books.csv")

# Import the books.csv file as a DataFrame
books_df = pd.read_csv(csv_path, encoding="utf-8")
books_df.head(20)
# Out:
#     id   book_id  best_book_id   work_id  books_count        isbn  \
# 0    1   2767052       2767052   2792775          272   439023483
# 1    2         3             3   4640799          491   439554934
# 2    3     41865         41865   3212258          226   316015849
# 3    4      2657          2657   3275794          487    61120081
# 4    5      4671          4671    245494         1356   743273567
# 5    6  11870085      11870085  16827462          226   525478817
# 6    7      5907          5907   1540236          969   618260307
# 7    8      5107          5107   3036731          360   316769177
# 8    9       960           960   3338963          311  1416524797
# 9   10      1885          1885   3060926         3455   679783261
# 10  11     77203         77203   3295919          283  1594480001
# 11  12  13335037      13335037  13155899          210    62024035
# 12  13      5470          5470    153313          995   451524934
# ...

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
# Only keep: "isbn", "original_publication_year", "original_title", "authors",
# "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"
reduced_df = books_df[["authors", "isbn", "original_publication_year", "original_title",
                       "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"]]
reduced_df.head(20)
# Out:
#                                               authors        isbn  \
# 0                                     Suzanne Collins   439023483
# 1                         J.K. Rowling, Mary GrandPré   439554934
# 2                                     Stephenie Meyer   316015849
# 3                                          Harper Lee    61120081
# 4                                 F. Scott Fitzgerald   743273567
# 5                                          John Green   525478817
# 6                                      J.R.R. Tolkien   618260307
# 7                                       J.D. Salinger   316769177
# 8                                           Dan Brown  1416524797
# 9                                         Jane Austen   679783261
# 10                                    Khaled Hosseini  1594480001
# 11                                      Veronica Roth    62024035
# 12            George Orwell, Erich Fromm, Celâl Üster   451524934
# ...

# %%
reduced_df.count().head()
# Out:
# authors                      10000
# isbn                          9300
# original_publication_year     9979
# original_title                9415
# ratings_1                    10000
# dtype: int64

# %%
grouped_df = reduced_df.groupby ("authors")
grouped_df.head(20)
# Out:
#                                                 authors        isbn  \
# 0                                       Suzanne Collins   439023483
# 1                           J.K. Rowling, Mary GrandPré   439554934
# 2                                       Stephenie Meyer   316015849
# 3                                            Harper Lee    61120081
# 4                                   F. Scott Fitzgerald   743273567
# 5                                            John Green   525478817
# 6                                        J.R.R. Tolkien   618260307
# 7                                         J.D. Salinger   316769177
# 8                                             Dan Brown  1416524797
# 9                                           Jane Austen   679783261
# 10                                      Khaled Hosseini  1594480001
# 11                                        Veronica Roth    62024035
# 12              George Orwell, Erich Fromm, Celâl Üster   451524934
# ...

# %%
grouped_df.count().head()
# Out:
#                                isbn  original_publication_year  \
# authors
# A. Manette Ansay                  1                          1
# A. Meredith Walters               0                          2
# A.A. Milne, Ernest H. Shepard     6                          6
# A.C. Gaughen                      1                          1
# A.G. Howard                       2                          2
#
#                                original_title  ratings_1  ratings_2  \
# authors
# A. Manette Ansay                            1          1          1
# A. Meredith Walters                         1          2          2
# A.A. Milne, Ernest H. Shepard               5          6          6
# A.C. Gaughen                                1          1          1
# A.G. Howard                                 2          2          2
#
#                                ratings_3  ratings_4  ratings_5
# authors
# A. Manette Ansay                       1          1          1
# ...
